# %%
string = '...'

# %%
def rev_compliment(s):
    c = s[::-1]
    rev_c = ''
    for i in c:
        if i == 'T':
            rev_c += 'A'
        elif i == 'A':
            rev_c += 'T'
        elif i == 'C':
            rev_c += 'G'
        elif i == 'G':
            rev_c += 'C'
    return rev_c

# %%
string[::-1]
# Out:
# 'TGGCCCAAAA'

# %%
rev_compliment(string)
# Out:
# '...'
